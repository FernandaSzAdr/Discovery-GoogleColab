# %% [markdown]
# <a href="https://colab.research.google.com/github/FernandaSzAdr/Discovery-GoogleColab/blob/master/main.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 1 - Importes

# %% [markdown]
# ## Importar dados do GitHub

# %%
# !git clone https://github.com/FernandaSzAdr/Discovery-GoogleColab.git
# Out:
# Cloning into 'Discovery-GoogleColab'...
# remote: Enumerating objects: 12, done.
# remote: Counting objects: 100% (12/12), done.
# remote: Compressing objects: 100% (10/10), done.
# remote: Total 12 (delta 1), reused 0 (delta 0), pack-reused 0
# Unpacking objects: 100% (12/12), done.

# %% [markdown]
# ---

# %% [markdown]
# ## Importar dados do Google Drive

# %%
# Load the Drive helper and mount
from google.colab import drive

# This will prompt for authorization.
drive.mount('/content/drive/')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive/

# %% [markdown]
# ---

# %% [markdown]
# ## Importando bibliotecas

# %%
import cv2
import numpy as np 
from matplotlib import pyplot as plt
# %matplotlib inline

# %% [markdown]
# # 2 - Instalações

# %% [markdown]
# ## Instalando bibliotecas

# %%
# !pip install imutils

# %% [markdown]
# # 3 - Códigos

# %% [markdown]
# ## Exemplo códigos

# %% [markdown]
# ### OpenCV e Matplotlib

# %%
image = cv2.imread('Discovery-GoogleColab/imagens/car.png',0)

fig = plt.figure(figsize=(10,10))
ax = fig.add_subplot(1,1,1, xticks=[], yticks=[])
ax.imshow(image,cmap='gray')
plt.title('Imagem original')
# Out:
# Text(0.5, 1.0, 'Imagem original')

# %%
r = 100.0 / image.shape[1]
dim = (100, int(image.shape[0] * r))

resized = cv2.resize(image, dim, interpolation = cv2.INTER_AREA)

fig = plt.figure(figsize=(10,10))
ax = fig.add_subplot(1,1,1, xticks=[], yticks=[])
ax.imshow(resized,cmap='gray')
plt.title('Imagem resized')
# Out:
# Text(0.5, 1.0, 'Imagem resized')

# %%
(h, w) = image.shape[:2]
center = (w / 2, h / 2)

M = cv2.getRotationMatrix2D(center, 180, 1.0)
rotated = cv2.warpAffine(image, M, (w, h))

fig = plt.figure(figsize=(10,10))
ax = fig.add_subplot(1,1,1, xticks=[], yticks=[])
ax.imshow(rotated,cmap='gray')
plt.title('Imagem rotated')
# Out:
# Text(0.5, 1.0, 'Imagem rotated')

# %% [markdown]
# ### Listas e prints

# %%
listinha = ['pão', 'queijo', 'ovos']

listinha
# Out:
# ['pão', 'queijo', 'ovos']

# %% [markdown]
# ### IPDB

# %%
# !pip install ipdb

# %%
for item in listinha:
  import ipdb; ipdb.set_trace()
  print(item)

# %% [markdown]
# # 4 - Explorando o Markdown

# %% [markdown]
# ## Umas coisinhas a mais...

# %% [markdown]
# <img src="https://github.com/FernandaSzAdr/Discovery-GoogleColab/blob/master/imagens/pylady_geek.png?raw=1" style="width:350px;height:270px;">
# <caption><center> <u> <font color='purple'> **Figure 1** </u><font color='purple'>  : **Imagenzinha carregada do GitHub**</center></caption>
#
#
#   Aqui a gente escreve uma descrição super legal do nosso código, para ajudar os amiguinhos a entenderem *ou quase* o que você fez.

# %% [markdown]
# Também da  para vincular URLs, tipo essa linda aqui: [PyLadies Brasil](http://brasil.pyladies.com/)
#
# Ou fazer listinhas:
# *   Item 1 ...
# *   Item 2 ...
#
# Ou descrever um pseudo código ou o seu código mesmo:
#
# ```python
# def function(mensage):
#     if mensagem:
#        return ("The Mensage for the people is: {}."
#                "Think about this!".format(mensage))
#     else:
#         return ("There aren't mensage for the people :(")
# ```

# %% [markdown]
# # 5 - Informações sobre "sua" máquina

# %% [markdown]
# ### GPU está ativada?

# %%
import tensorflow as tf
tf.test.gpu_device_name()
# Out:
# '/device:GPU:0'

# %% [markdown]
# ### Qual GPU está sendo utilizada?

# %%
from tensorflow.python.client import device_lib
device_lib.list_local_devices()
# Out:
# [name: "/device:CPU:0"
#  device_type: "CPU"
#  memory_limit: 268435456
#  locality {
#  }
#  incarnation: 2394026955980556180, name: "/device:XLA_CPU:0"
#  device_type: "XLA_CPU"
#  memory_limit: 17179869184
#  locality {
#  }
#  incarnation: 16524609872629400694
#  physical_device_desc: "device: XLA_CPU device", name: "/device:XLA_GPU:0"
#  device_type: "XLA_GPU"
#  memory_limit: 17179869184
#  locality {
#  }
#  incarnation: 6500097299304146086
#  physical_device_desc: "device: XLA_GPU device", name: "/device:GPU:0"
#  device_type: "GPU"
#  memory_limit: 11276884378
#  locality {
#    bus_id: 1
#    links {
#    }
#  }
#  incarnation: 2952882626415874104
#  physical_device_desc: "device: 0, name: Tesla K80, pci bus id: 0000:00:04.0, compute capability: 3.7"]

# %% [markdown]
# ### Informações sobre a RAM:

# %%
# !cat /proc/meminfo
# Out:
# MemTotal:       13335268 kB
# MemFree:        10340100 kB
# MemAvailable:   12187424 kB
# Buffers:           72912 kB
# Cached:          1928636 kB
# SwapCached:            0 kB
# Active:           887220 kB
# Inactive:        1735100 kB
# Active(anon):     591012 kB
# Inactive(anon):     2392 kB
# Active(file):     296208 kB
# Inactive(file):  1732708 kB
# Unevictable:           0 kB
# Mlocked:               0 kB
# SwapTotal:             0 kB
# SwapFree:              0 kB
# Dirty:               224 kB
# Writeback:             0 kB
# AnonPages:        620836 kB
# Mapped:           422364 kB
# Shmem:              2948 kB
# Slab:             158652 kB
# SReclaimable:     119096 kB
# SUnreclaim:        39556 kB
# KernelStack:        4048 kB
# PageTables:         6660 kB
# NFS_Unstable:          0 kB
# Bounce:                0 kB
# WritebackTmp:          0 kB
# CommitLimit:     6667632 kB
# Committed_AS:    2243560 kB
# VmallocTotal:   34359738367 kB
# VmallocUsed:           0 kB
# ...

# %% [markdown]
# ### Informações sobre a CPU:

# %%
# !cat /proc/cpuinfo
# Out:
# processor	: 0
# vendor_id	: GenuineIntel
# cpu family	: 6
# model		: 79
# model name	: Intel(R) Xeon(R) CPU @ 2.20GHz
# stepping	: 0
# microcode	: 0x1
# cpu MHz		: 2200.000
# cache size	: 56320 KB
# physical id	: 0
# siblings	: 2
# core id		: 0
# cpu cores	: 1
# apicid		: 0
# initial apicid	: 0
# fpu		: yes
# fpu_exception	: yes
# cpuid level	: 13
# wp		: yes
# flags		: fpu vme de pse tsc msr pae mce cx8 apic sep mtrr pge mca cmov pat pse36 clflush mmx fxsr sse sse2 ss ht syscall nx pdpe1gb rdtscp lm constant_tsc rep_good nopl xtopology nonstop_tsc cpuid tsc_known_freq pni pclmulqdq ssse3 fma cx16 pcid sse4_1 sse4_2 x2apic movbe popcnt aes xsave avx f16c rdrand hypervisor lahf_lm abm 3dnowprefetch invpcid_single pti ssbd ibrs ibpb stibp fsgsbase tsc_adjust bmi1 hle avx2 smep bmi2 erms invpcid rtm rdseed adx smap xsaveopt arat arch_capabilities
# bugs		: cpu_meltdown spectre_v1 spectre_v2 spec_store_bypass l1tf
# bogomips	: 4400.00
# clflush size	: 64
# cache_alignment	: 64
# ...

# %%
# !ls
# Out:
# elephant.jpg  Koala.jpg  sample_data
